# %% [markdown]
# <a href="https://colab.research.google.com/github/dmr059/Python/blob/main/Jazz_Trivia_Game.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# This fun little quiz program was inspired by my jazz history class. I wanted to experiement with user input and if/elif/else statments and thought what better way to do that than to combine jazz review with programming!
#
# This program utilizes:
#
# • input()
#
# • scoring system with feedback
#
# • if/elif/else statments
#
# • str() conversion
#
# • print() function
#
# • or function

# %%
score = 0

option1 = "Louis Armstrong"
option2 = "Cillford Brown"
option3 = "Miles Davis"
option4 = "Dizzy Gillespie"

print("Which prolific trumpet player was know for hiting all time high notes within his compositions?")

print("A.", option1)
print("B.", option2)
print("C.", option3)
print("D.", option4)

answer = input()

if answer == "D" or answer == "d":
  score += 100
  print("Correct! You've earned 100 pts!")
else:
  print("Nope, sorry!")
  score = score - 100

print("Your current score is " + str(score) + "pts")

option1 = "Swing"
option2 = "Bebop"
option3 = "Free Jazz"
option4 = "Hardbop"

print("Which era of jazz became the most commercialized style with the help of The Glenn Miller Band?")

print("A.", option1)
print("B.", option2)
print("C.", option3)
print("D.", option4)

answer = input()

if answer == "A" or answer == "a":
  print("Correct! You've earned 100 pts!")
  score += 100
else:
  print("Nope, sorry!")
  score = score - 100

print("Your current score is " + str(score) + "pts")

option1 = "Samba"
option2 = "Afro-Cuban"
option3 = "Bossa Nova"
option4 = "Cha Cha"

print("Which style of jazz did saxophonist Stan Getz help populized within the United States?")

print("A.", option1)
print("B.", option2)
print("C.", option3)
print("D.", option4)

answer = input()

if answer == "C" or answer == "c":
  print("Correct! You've earned 100pts!")
  score += 100
else:
  print("Nope, sorry!")
  score = score - 100

print("Your current score is " + str(score) + "pts")

option1 = "9/8"
option2 = "5/4"
option3 = "6/8"
option4 = "4/4"

print("Which time signature is the iconic song Take Five written by Dave Brubeck written in?")

print("A.", option1)
print("B.", option2)
print("C.", option3)
print("D.", option4)

answer = input()

if answer == "B" or answer == "b":
  print("Correct! You've earned 100pts!")
  score += 100
else:
  print("Nope, sorry!")
  score = score - 100

print("Your current score is " + str(score) + "pts")

option1 = "Art Blakey"
option2 = "Max Roach"
option3 = "Gene Kupra"
option4 = "Charles Mingus"

print("Which jazz drummer, with the help of trumpet player Clifford Brown, was instrumental in creating the Hardbop sound?")

print("A.", option1)
print("B.", option2)
print("C.", option3)
print("D.", option4)

answer = input()

if answer == "B" or answer == "b":
  print("Correct! You've earned 100pts!")
  score += 100
else:
  print("Nope, sorry!")
  score = score - 100

print("Thanks for playing!")

if score == 500:
  print("You've recieved a perfect score! What a cool cat!")
elif score == 400 or score == 300:
  print("Your score was " + str(score) + "." + " Not so bad, what a vibe!")
elif score == 200 or score == 100:
  print("Your score was " + str(score) + "." + " Better luck, Chuck, hit those books!")
else:
  print("Your score was " + str(score) + "." + " Ouch!")
# Out:
# Which prolific trumpet player was know for hiting all time high notes within his compositions?
# A. Louis Armstrong
# B. Cillford Brown
# C. Miles Davis
# D. Dizzy Gillespie
# A
# Nope, sorry!
# Your current score is -100pts
# Which era of jazz became the most commercialized style with the help of The Glenn Miller Band?
# A. Swing
# B. Bebop
# C. Free Jazz
# D. Hardbop
# D
# Nope, sorry!
# Your current score is -200pts
# Which style of jazz did saxophonist Stan Getz help populized within mainstream culture?
# A. Samba
# B. Afro-Cuban
# C. Bossa Nova
# D. Cha Cha
# A
# Nope, sorry!
# Your current score is -300pts
# Which time signature is the iconic song Take Five written by Dave Brubeck written in?
# A. 9/8
# B. 5/4
# C. 6/8
# D. 4/4
# C
# Nope, sorry!
# Your current score is -400pts
# Which jazz drummer, with the help of trumpet player Clifford Brown, was instrumental in creating the Hardbop sound?
# A. Art Blakey
# B. Max Roach
# C. Gene Kupra
# D. Charles Mingus
# B
# ...
